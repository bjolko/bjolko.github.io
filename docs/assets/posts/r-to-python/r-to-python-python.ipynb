# %%
import pandas as pd

pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# # Reading files

# %%
df = pd.read_csv('Walmart_Store_sales.csv')

# %% [markdown]
# # Data overview

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31        2.57
# 1      1  12-02-2010    1641957.44             1        38.51        2.55
# 2      1  19-02-2010    1611968.17             0        39.93        2.51
# 3      1  26-02-2010    1409727.59             0        46.63        2.56
# 4      1  05-03-2010    1554806.68             0        46.50        2.62
#
#      CPI  Unemployment
# 0 211.10          8.11
# 1 211.24          8.11
# 2 211.29          8.11
# 3 211.32          8.11
# 4 211.35          8.11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %% [markdown]
# # Data manipulation

# %% [markdown]
# ## Select columns

# %%
df[['Store', 'Date', 'Weekly_Sales']].head()
# Out:
#    Store        Date  Weekly_Sales
# 0      1  05-02-2010    1643690.90
# 1      1  12-02-2010    1641957.44
# 2      1  19-02-2010    1611968.17
# 3      1  26-02-2010    1409727.59
# 4      1  05-03-2010    1554806.68

# %% [markdown]
# ## Filter rows

# %% [markdown]
# Two options

# %%
df.query('Store == 1').head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31        2.57
# 1      1  12-02-2010    1641957.44             1        38.51        2.55
# 2      1  19-02-2010    1611968.17             0        39.93        2.51
# 3      1  26-02-2010    1409727.59             0        46.63        2.56
# 4      1  05-03-2010    1554806.68             0        46.50        2.62
#
#      CPI  Unemployment
# 0 211.10          8.11
# 1 211.24          8.11
# 2 211.29          8.11
# 3 211.32          8.11
# 4 211.35          8.11

# %%
df[df['Store'] == 1].head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31        2.57
# 1      1  12-02-2010    1641957.44             1        38.51        2.55
# 2      1  19-02-2010    1611968.17             0        39.93        2.51
# 3      1  26-02-2010    1409727.59             0        46.63        2.56
# 4      1  05-03-2010    1554806.68             0        46.50        2.62
#
#      CPI  Unemployment
# 0 211.10          8.11
# 1 211.24          8.11
# 2 211.29          8.11
# 3 211.32          8.11
# 4 211.35          8.11

# %% [markdown]
# ## Sort rows

# %%
df.sort_values('Weekly_Sales', ascending=False).head()
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1905     14  24-12-2010    3818686.45             0        30.59        3.14
# 2763     20  24-12-2010    3766687.43             0        25.17        3.14
# 1333     10  24-12-2010    3749057.69             0        57.06        3.24
# 527       4  23-12-2011    3676388.98             0        35.92        3.10
# 1762     13  24-12-2010    3595903.20             0        34.90        2.85
#
#         CPI  Unemployment
# 1905 182.54          8.72
# 2763 204.64          7.48
# 1333 126.98          9.00
# 527  129.98          5.14
# 1762 126.98          7.79

# %% [markdown]
# ## Create or modify a column

# %%
df.assign(
    Date = lambda x: pd.to_datetime(x['Date']),
    Weekly_Sales_K = lambda x: x['Weekly_Sales'] / 1000
).head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-05-02    1643690.90             0        42.31        2.57
# 1      1 2010-12-02    1641957.44             1        38.51        2.55
# 2      1 2010-02-19    1611968.17             0        39.93        2.51
# 3      1 2010-02-26    1409727.59             0        46.63        2.56
# 4      1 2010-05-03    1554806.68             0        46.50        2.62
#
#      CPI  Unemployment  Weekly_Sales_K
# 0 211.10          8.11         1643.69
# 1 211.24          8.11         1641.96
# 2 211.29          8.11         1611.97
# 3 211.32          8.11         1409.73
# 4 211.35          8.11         1554.81

# %% [markdown]
# ## Rename columns

# %%
df.rename(columns={'Holiday_Flag': 'is_holiday'}).head()
# Out:
#    Store        Date  Weekly_Sales  is_holiday  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90           0        42.31        2.57
# 1      1  12-02-2010    1641957.44           1        38.51        2.55
# 2      1  19-02-2010    1611968.17           0        39.93        2.51
# 3      1  26-02-2010    1409727.59           0        46.63        2.56
# 4      1  05-03-2010    1554806.68           0        46.50        2.62
#
#      CPI  Unemployment
# 0 211.10          8.11
# 1 211.24          8.11
# 2 211.29          8.11
# 3 211.32          8.11
# 4 211.35          8.11

# %% [markdown]
# ## Groupby and summarise

# %%
(
    df
    .groupby('Store')
    .agg(
        total_sales = ('Weekly_Sales', 'sum')
    )
    .head()
)
# Out:
#        total_sales
# Store
# 1     222402808.85
# 2     275382440.98
# 3      57586735.07
# 4     299543953.38
# 5      45475688.90

# %% [markdown]
# ## Window functions

# %%
(
    df
    [['Store', 'Date', 'Weekly_Sales']]
    .assign(
        total_sales = lambda x: x.groupby('Store')['Weekly_Sales'].transform('sum')
    ).head()
)
# Out:
#    Store        Date  Weekly_Sales  total_sales
# 0      1  05-02-2010    1643690.90 222402808.85
# 1      1  12-02-2010    1641957.44 222402808.85
# 2      1  19-02-2010    1611968.17 222402808.85
# 3      1  26-02-2010    1409727.59 222402808.85
# 4      1  05-03-2010    1554806.68 222402808.85

# %% [markdown]
# # R pipes and Method chaining

# %%
def lower_names(df):
    df.columns = df.columns.str.lower()
    return df

# %%
df = pd.read_csv('Walmart_Store_sales.csv')

# %%
(
    df
    .pipe(lower_names)
    .loc[lambda x: x['holiday_flag'] == 1]
    [['date', 'store', 'weekly_sales']]
    .assign(
        date = lambda x: pd.to_datetime(x['date'], format='%d-%m-%Y')
    )
    .sort_values(by=['date', 'weekly_sales'], ascending=False)
    .groupby('date')
    .head(5)
    .style.format({
        'weekly_sales': '{:,.0f}',
        'date': '{:%Y-%m-%d}'
    })
    
)
# Out:
# <style  type="text/css" >
# </style><table id="T_5f88e77e_aa37_11eb_95bf_50eb71577262" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >date</th>        <th class="col_heading level0 col1" >store</th>        <th class="col_heading level0 col2" >weekly_sales</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row0" class="row_heading level0 row0" >1851</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row0_col0" class="data row0 col0" >2012-09-07</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row0_col1" class="data row0 col1" >13</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row0_col2" class="data row0 col2" >2,165,796</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row1" class="row_heading level0 row1" >564</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row1_col0" class="data row1 col0" >2012-09-07</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row1_col1" class="data row1 col1" >4</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row1_col2" class="data row1 col2" >2,125,105</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row2" class="row_heading level0 row2" >2852</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row2_col0" class="data row2 col0" >2012-09-07</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row2_col1" class="data row2 col1" >20</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row2_col2" class="data row2 col2" >2,080,529</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row3" class="row_heading level0 row3" >1994</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row3_col0" class="data row3 col0" >2012-09-07</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row3_col1" class="data row3 col1" >14</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row3_col2" class="data row3 col2" >1,904,512</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row4" class="row_heading level0 row4" >278</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row4_col0" class="data row4 col0" >2012-09-07</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row4_col1" class="data row4 col1" >2</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row4_col2" class="data row4 col2" >1,898,777</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row5" class="row_heading level0 row5" >2822</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row5_col0" class="data row5 col0" >2012-02-10</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row5_col1" class="data row5 col1" >20</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row5_col2" class="data row5 col2" >2,462,978</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row6" class="row_heading level0 row6" >534</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row6_col0" class="data row6 col0" >2012-02-10</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row6_col1" class="data row6 col1" >4</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row6_col2" class="data row6 col2" >2,374,661</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row7" class="row_heading level0 row7" >1392</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row7_col0" class="data row7 col0" >2012-02-10</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row7_col1" class="data row7 col1" >10</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row7_col2" class="data row7 col2" >2,218,596</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row8" class="row_heading level0 row8" >248</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row8_col0" class="data row8 col0" >2012-02-10</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row8_col1" class="data row8 col1" >2</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row8_col2" class="data row8 col2" >2,103,323</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row9" class="row_heading level0 row9" >1964</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row9_col0" class="data row9 col0" >2012-02-10</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row9_col1" class="data row9 col1" >14</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row9_col2" class="data row9 col2" >2,077,256</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row10" class="row_heading level0 row10" >2816</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row10_col0" class="data row10 col0" >2011-12-30</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row10_col1" class="data row10 col1" >20</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row10_col2" class="data row10 col2" >2,043,245</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row11" class="row_heading level0 row11" >528</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row11_col0" class="data row11 col0" >2011-12-30</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row11_col1" class="data row11 col1" >4</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row11_col2" class="data row11 col2" >2,007,106</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row12" class="row_heading level0 row12" >1815</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row12_col0" class="data row12 col0" >2011-12-30</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row12_col1" class="data row12 col1" >13</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row12_col2" class="data row12 col2" >1,969,057</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row13" class="row_heading level0 row13" >1386</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row13_col0" class="data row13 col0" >2011-12-30</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row13_col1" class="data row13 col1" >10</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row13_col2" class="data row13 col2" >1,930,690</td>
#             </tr>
#             <tr>
#                         <th id="T_5f88e77e_aa37_11eb_95bf_50eb71577262level0_row14" class="row_heading level0 row14" >1958</th>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row14_col0" class="data row14 col0" >2011-12-30</td>
#                         <td id="T_5f88e77e_aa37_11eb_95bf_50eb71577262row14_col1" class="data row14 col1" >14</td>
#                         <td id="T_5f88e77e_aa
